# %% [markdown]
# - jak použít knihovny a zástupné označení

# %%
import math as m

a = m.sin(30)
print(a)
# print(a)

a = 10
print (a * 10)
# Out:
# -0.9880316240928618
# 100

# %%
import pandapower as pp
net = pp.create_empty_network(name='Pokus', f_hz=50.0, sn_mva=1, add_stdtypes=True)
pp.create_bus(net, vn_kv, name=None, index=None, geodata=None, type='b', zone=None, in_service=True, max_vm_pu=nan, min_vm_pu=nan, coords=None, **kwargs)
# Out:
#   Cell In[3], line 3
#     pp.create_bus(net, vn_kv, name=None, index=None, geodata=None, type='b', zone=None, in_service=True, max_vm_pu=nan, min_vm_pu=nan, coords=None, **kwargs)
#                                                                                                                                                              ^
# SyntaxError: invalid non-printable character U+F0C1

# %%
import pandapower as pp

#print(pp.available_std_types(net,"trafo"))
print(pp.available_std_types(net,"line"))

#create empty net
net = pp.create_empty_network(name='POkus', f_hz=50.0, sn_mva=1200, add_stdtypes=True) 

#create buses
bus1 = pp.create_bus(net, name="Přívod", vn_kv=110, type="b")
bus2 = pp.create_bus(net, name="VN", vn_kv=22, type="b")
bus3 = pp.create_bus(net, name="NN", vn_kv=0.4, type="b")

# trafo1 = pp.create_transformer(net, bus1, bus2, name="Trafo", std_type="0.4 MVA")
trafo1 = pp.create_transformer_from_parameters(net= net, hv_bus=bus1,
    lv_bus = bus2,
    sn_mva= 22,
    vn_hv_kv= 110,
    vn_lv_kv= 22,
    vkr_percent= 6,
    vk_percent=6,
    pfe_kw=1,
    i0_percent=1)
trafo2 = pp.create_transformer_from_parameters(net= net, hv_bus=bus1,
    lv_bus = bus2,
    sn_mva= 1.6,
    vn_hv_kv= 22,
    vn_lv_kv= 0.4,
    vkr_percent= 6,
    vk_percent=6,
    pfe_kw=1,
    i0_percent=1)

net.bus # show bus table
net.trafo # show bus table
# Out:
#                                   c_nf_per_km  r_ohm_per_km  x_ohm_per_km  \
# NAYY 4x50 SE                           210.00        0.6420         0.083
# NAYY 4x120 SE                          264.00        0.2250         0.080
# NAYY 4x150 SE                          261.00        0.2080         0.080
# NA2XS2Y 1x95 RM/25 12/20 kV            216.00        0.3130         0.132
# NA2XS2Y 1x185 RM/25 12/20 kV           273.00        0.1610         0.117
# NA2XS2Y 1x240 RM/25 12/20 kV           304.00        0.1220         0.112
# NA2XS2Y 1x95 RM/25 6/10 kV             315.00        0.3130         0.123
# NA2XS2Y 1x185 RM/25 6/10 kV            406.00        0.1610         0.110
# NA2XS2Y 1x240 RM/25 6/10 kV            456.00        0.1220         0.105
# NA2XS2Y 1x150 RM/25 12/20 kV           250.00        0.2060         0.116
# NA2XS2Y 1x120 RM/25 12/20 kV           230.00        0.2530         0.119
# NA2XS2Y 1x70 RM/25 12/20 kV            190.00        0.4430         0.132
# ...

# %%
import pandapower as pp
#create empty net
net = pp.create_empty_network() 

#create buses
b1 = pp.create_bus(net, vn_kv=22.0, name="Bus 1")
b2 = pp.create_bus(net, vn_kv=0.4, name="Bus 2")
b3 = pp.create_bus(net, vn_kv=0.4, name="Bus 3")

#create bus elements
pp.create_ext_grid(net, bus=b1, vm_pu=1.02, name="Grid Connection")
pp.create_load(net, bus=b3, p_mw=0.1, q_mvar=0.05, name="Load")

#create branch elements
#tid = pp.create_transformer(net, hv_bus=b1, lv_bus=b2, std_type="0.4 MVA 20/0.4 kV", name="Trafo")
tid = pp.create_transformer(net, hv_bus=b1, lv_bus=b2, std_type="1.6 MVA 22/0.4 kV", name="Trafo")
pp.create_line(net, from_bus=b2, to_bus=b3, length_km=0.1, name="Line",std_type="NAYY 4x50 SE")  

#net.trafo
# Out:
# ---------------------------------------------------------------------------
# UserWarning                               Traceback (most recent call last)
# Cell In[4], line 16
#      12 pp.create_load(net, bus=b3, p_mw=0.1, q_mvar=0.05, name="Load")
#      14 #create branch elements
#      15 #tid = pp.create_transformer(net, hv_bus=b1, lv_bus=b2, std_type="0.4 MVA 20/0.4 kV", name="Trafo")
# ---> 16 tid = pp.create_transformer(net, hv_bus=b1, lv_bus=b2, std_type="1.6 MVA 22/0.4 kV", name="Trafo")
#      17 pp.create_line(net, from_bus=b2, to_bus=b3, length_km=0.1, name="Line",std_type="NAYY 4x50 SE")
#      19 #net.trafo
#
# File c:\Users\Martin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandapower\create.py:2643, in create_transformer(net, hv_bus, lv_bus, std_type, name, tap_pos, in_service, index, max_loading_percent, parallel, df, tap_dependent_impedance, vk_percent_characteristic, vkr_percent_characteristic, pt_percent, oltc, xn_ohm, tap2_pos, **kwargs)
# ...

# %%
net.bus
# Out:
#     name  vn_kv type  zone  in_service
# 0  Bus 1   22.0    b  None        True
# 1  Bus 2    0.4    b  None        True
# 2  Bus 3    0.4    b  None        True

# %%
net.load
# Out:
#    name  bus  p_mw  q_mvar  const_z_percent  const_i_percent  sn_mva  scaling  \
# 0  Load    2   0.1    0.05              0.0              0.0     NaN      1.0
#
#    in_service type
# 0        True  wye

# %%
pp.runpp(net)
net.res_bus
# Out:
#       vm_pu   va_degree      p_mw    q_mvar
# 0  1.020000    0.000000 -0.106441 -0.052169
# 1  1.111938 -150.621274  0.000000  0.000000
# 2  1.072002 -149.906272  0.100000  0.050000

# %%
net.res_line
# Out:
#    p_from_mw  q_from_mvar  p_to_mw  q_to_mvar     pl_mw   ql_mvar  i_from_ka  \
# 0   0.104364     0.050563     -0.1      -0.05  0.004364  0.000563   0.150535
#
#     i_to_ka      i_ka  vm_from_pu  va_from_degree  vm_to_pu  va_to_degree  \
# 0  0.150535  0.150535    1.111938     -150.621274  1.072002   -149.906272
#
#    loading_percent
# 0       106.010855

# %%
pp.create_switch(net, bus=b3, element=line, et="l", closed=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 pp.create_switch(net, bus=b3, element=line, et="l", closed=False)
#
# NameError: name 'line' is not defined
